# %%
# !pip install beautifulsoup4
# !pip install requests
# !pip install pandas
# !pip install openpyxl

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://takeuforward.org/strivers-a2z-dsa-course/strivers-a2z-dsa-course-sheet-2/"

# %%
html_doc = requests.get(url).text
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
li = []

# %%
soup.find_all('details')[33].find_all('tr')[1:][1].find_all('td')[1].txt

# %%
topic = ""
for idx, i in enumerate(soup.find_all('details')):
    
    if i.has_attr('closed'):
        for jidx, j in enumerate(i.find_all('tr')[1:]):
            dict = {}
            dict['heading'] = i.summary.text
            dict['topic'] = topic
            dict['Question'] = j.find_all('td')[1].text
            for kidx, k in enumerate(j.find_all('a')):
                dict[kidx] = k['href']

            li.append(dict)
    else:
        topic = i.summary.text

# %%
# convert into dataframe

df = pd.DataFrame(data=li)

# %%
df
# Out:
#                                                heading  \
# 0    Step 1.1: Things to Know in C++/Java/Python or...
# 1    Step 1.1: Things to Know in C++/Java/Python or...
# 2    Step 1.1: Things to Know in C++/Java/Python or...
# 3    Step 1.1: Things to Know in C++/Java/Python or...
# 4    Step 1.1: Things to Know in C++/Java/Python or...
# ..                                                 ...
# 451                           Step 18.1: Hard Problems
# 452                           Step 18.1: Hard Problems
# 453                           Step 18.1: Hard Problems
# 454                           Step 18.1: Hard Problems
# 455                           Step 18.1: Hard Problems
#
#                                                  topic  \
# 0                             Step 1: Learn the basics
# 1                             Step 1: Learn the basics
# 2                             Step 1: Learn the basics
# 3                             Step 1: Learn the basics
# ...

# %%
df.to_excel("Strivers A2Z DSA.xlsx", index=False)
